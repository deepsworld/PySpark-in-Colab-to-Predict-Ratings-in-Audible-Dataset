# %%
# Required for installation of Spark in Google Colab

# !apt-get install openjdk-8-jdk-headless -qq > /dev/null
# !wget -q https://www-us.apache.org/dist/spark/spark-2.4.3/spark-2.4.3-bin-hadoop2.7.tgz
# !tar xf spark-2.4.3-bin-hadoop2.7.tgz
# !pip install -q findspark

import os
os.environ["JAVA_HOME"] = "/usr/lib/jvm/java-8-openjdk-amd64"
os.environ["SPARK_HOME"] = "/content/spark-2.4.3-bin-hadoop2.7"

import findspark
findspark.init()

# %% [markdown]
# # Creates a Spark session

# %%
from pyspark.sql import SparkSession
spark = SparkSession.builder \
    .master("local[*]") \
    .appName("Learning_Spark") \
    .getOrCreate()

# %%
# Can be used to import local files to Colab
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-f9d361f0-dd7d-48b7-aa17-19b0a834cf0e" name="files[]" multiple disabled />
#      <output id="result-f9d361f0-dd7d-48b7-aa17-19b0a834cf0e">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# {}

# %%
data = spark.read.csv('/content/sample_data/california_housing_train.csv',inferSchema=True, header=True)

# %%
# show top 5 rows of the dataframe
data.show()
# Out:
# +---------+--------+------------------+-----------+--------------+----------+----------+-------------+------------------+
# |longitude|latitude|housing_median_age|total_rooms|total_bedrooms|population|households|median_income|median_house_value|
# +---------+--------+------------------+-----------+--------------+----------+----------+-------------+------------------+
# |  -114.31|   34.19|              15.0|     5612.0|        1283.0|    1015.0|     472.0|       1.4936|           66900.0|
# |  -114.47|    34.4|              19.0|     7650.0|        1901.0|    1129.0|     463.0|         1.82|           80100.0|
# |  -114.56|   33.69|              17.0|      720.0|         174.0|     333.0|     117.0|       1.6509|           85700.0|
# |  -114.57|   33.64|              14.0|     1501.0|         337.0|     515.0|     226.0|       3.1917|           73400.0|
# |  -114.57|   33.57|              20.0|     1454.0|         326.0|     624.0|     262.0|        1.925|           65500.0|
# |  -114.58|   33.63|              29.0|     1387.0|         236.0|     671.0|     239.0|       3.3438|           74000.0|
# |  -114.58|   33.61|              25.0|     2907.0|         680.0|    1841.0|     633.0|       2.6768|           82400.0|
# |  -114.59|   34.83|              41.0|      812.0|         168.0|     375.0|     158.0|       1.7083|           48500.0|
# |  -114.59|   33.61|              34.0|     4789.0|        1175.0|    3134.0|    1056.0|       2.1782|           58400.0|
# |   -114.6|   34.83|              46.0|     1497.0|         309.0|     787.0|     271.0|       2.1908|           48100.0|
# |   -114.6|   33.62|              16.0|     3741.0|         801.0|    2434.0|     824.0|       2.6797|           86500.0|
# |   -114.6|    33.6|              21.0|     1988.0|         483.0|    1182.0|     437.0|        1.625|           62000.0|
# |  -114.61|   34.84|              48.0|     1291.0|         248.0|     580.0|     211.0|       2.1571|           48600.0|
# |  -114.61|   34.83|              31.0|     2478.0|         464.0|    1346.0|     479.0|        3.212|           70400.0|
# |  -114.63|   32.76|              15.0|     1448.0|         378.0|     949.0|     300.0|       0.8585|           45000.0|
# |  -114.65|   34.89|              17.0|     2556.0|         587.0|    1005.0|     401.0|       1.6991|           69100.0|
# |  -114.65|    33.6|              28.0|     1678.0|         322.0|     666.0|     256.0|       2.9653|           94900.0|
# |  -114.65|   32.79|              21.0|       44.0|          33.0|      64.0|      27.0|       0.8571|           25000.0|
# |  -114.66|   32.74|              17.0|     1388.0|         386.0|     775.0|     320.0|       1.2049|           44000.0|
# |  -114.67|   33.92|              17.0|       97.0|          24.0|      29.0|      15.0|       1.2656|           27500.0|
# +---------+--------+------------------+-----------+--------------+----------+----------+-------------+------------------+
# only showing top 20 rows

# %%
# to get the shape of the data
data.count(),  len(data.columns) # number of rows, number of columns
# Out:
# (17000, 9)

# %%
# prints the schema of the dataframe.
# it will return the datatypes and other details about the dataset.
# similar to the pandas df.describe() method.
data.printSchema()
# Out:
# root
#  |-- longitude: double (nullable = true)
#  |-- latitude: double (nullable = true)
#  |-- housing_median_age: double (nullable = true)
#  |-- total_rooms: double (nullable = true)
#  |-- total_bedrooms: double (nullable = true)
#  |-- population: double (nullable = true)
#  |-- households: double (nullable = true)
#  |-- median_income: double (nullable = true)
#  |-- median_house_value: double (nullable = true)

# %%
# only display selected columns 
data.select("median_income","median_house_value","housing_median_age") \
.show(15, truncate = False)
# Out:
# +-------------+------------------+------------------+
# |median_income|median_house_value|housing_median_age|
# +-------------+------------------+------------------+
# |1.4936       |66900.0           |15.0              |
# |1.82         |80100.0           |19.0              |
# |1.6509       |85700.0           |17.0              |
# |3.1917       |73400.0           |14.0              |
# |1.925        |65500.0           |20.0              |
# |3.3438       |74000.0           |29.0              |
# |2.6768       |82400.0           |25.0              |
# |1.7083       |48500.0           |41.0              |
# |2.1782       |58400.0           |34.0              |
# |2.1908       |48100.0           |46.0              |
# |2.6797       |86500.0           |16.0              |
# |1.625        |62000.0           |21.0              |
# |2.1571       |48600.0           |48.0              |
# |3.212        |70400.0           |31.0              |
# |0.8585       |45000.0           |15.0              |
# +-------------+------------------+------------------+
# only showing top 15 rows

# %%
# to get the statistical summary of the selected columns
data.describe(["median_income","median_house_value","housing_median_age", "longitude", "latitude"]).show()
# Out:
# +-------+------------------+------------------+------------------+-------------------+------------------+
# |summary|     median_income|median_house_value|housing_median_age|          longitude|          latitude|
# +-------+------------------+------------------+------------------+-------------------+------------------+
# |  count|             17000|             17000|             17000|              17000|             17000|
# |   mean| 3.883578100000021|207300.91235294117| 28.58935294117647|-119.56210823529375|  35.6252247058827|
# | stddev|1.9081565183791036|115983.76438720895|12.586936981660406| 2.0051664084260357|2.1373397946570867|
# |    min|            0.4999|           14999.0|               1.0|            -124.35|             32.54|
# |    max|           15.0001|          500001.0|              52.0|            -114.31|             41.95|
# +-------+------------------+------------------+------------------+-------------------+------------------+

# %%
# using the audible dataset

data = spark.read.csv('/content/all_english_audible.csv',inferSchema=True, header=True)

# %%
data.show(5)
# Out:
# +----------+--------------------+--------------------+------------------+--------------------+--------------------+-----+------+------------+------------+--------------------+
# |      asin|              author|            category|            length|                link|            narrator|price|rating|rating_count|release_date|               title|
# +----------+--------------------+--------------------+------------------+--------------------+--------------------+-----+------+------------+------------+--------------------+
# |      null|        Paul Stanley|Arts & Entertainment| 4 hrs and 38 mins|https://www.audib...|          Sean Pratt|20.52|   4.0|        78.0|  2019-04-30|      Backstage Pass|
# |B0052OM9XK|          Simon Pegg|Arts & Entertainment| 4 hrs and 50 mins|https://www.audib...|          Simon Pegg| 24.5|   4.5|       872.0|  2011-06-09|        Nerd Do Well|
# |B077XN66F8|        Sidney Lumet|Arts & Entertainment| 7 hrs and 23 mins|https://www.audib...| Richard M. Davidson|20.99|   5.0|        90.0|  2017-12-05|       Making Movies|
# |B00C75YMJ6|      Phil Robertson|Arts & Entertainment| 4 hrs and 57 mins|https://www.audib...|Al Robertson, Phi...|20.99|   4.5|       805.0|  2013-05-07| Happy, Happy, Happy|
# |B00DCD16GE|Robert Greenberg,...|Arts & Entertainment|24 hrs and 25 mins|https://www.audib...|    Robert Greenberg|52.95|   5.0|       585.0|  2013-07-08|How to Listen to ...|
# +----------+--------------------+--------------------+------------------+--------------------+--------------------+-----+------+------------+------------+--------------------+
# only showing top 5 rows

# %%
data.count(), len(data.columns)
# Out:
# (44384, 11)

# %%
data.printSchema()
# Out:
# root
#  |-- asin: string (nullable = true)
#  |-- author: string (nullable = true)
#  |-- category: string (nullable = true)
#  |-- length: string (nullable = true)
#  |-- link: string (nullable = true)
#  |-- narrator: string (nullable = true)
#  |-- price: string (nullable = true)
#  |-- rating: string (nullable = true)
#  |-- rating_count: double (nullable = true)
#  |-- release_date: string (nullable = true)
#  |-- title: string (nullable = true)

# %%
data.describe().show()
# Out:
# +-------+--------------------+-----------------+-------------------+--------------------+--------------------+-----------------+--------------------+------------------+------------------+-----------------+--------------------+
# |summary|                asin|           author|           category|              length|                link|         narrator|               price|            rating|      rating_count|     release_date|               title|
# +-------+--------------------+-----------------+-------------------+--------------------+--------------------+-----------------+--------------------+------------------+------------------+-----------------+--------------------+
# |  count|               41907|            44267|              44384|               44381|               44384|            43962|               44371|             44333|             44378|            44379|               44384|
# |   mean|     1.49163573135E9|             null|               null|                null|                null|             null|  15.660465163474786|3.3986489656883747|133.90545810987427|36.07142857142857|   734.9545454545455|
# | stddev|3.6267760469686264E8|             null|               null|                null|                null|             null|   9.539377901473062|1.7335096436394948|1288.4465007932351| 90.8384948293241|   875.4724154514809|
# |    min|          0525499652|"""Bo"" Bottomly"| 50 Things To Know"| Brig. Gen. Leo P...|    1 hr and 49 mins|"""Bo"" Bottomly"|       Denise Kirby"|         Stu Sone"|               0.0|              0.0|"""All the Living...|
# |    max|          B07TPLMXDW|     win c. kelly|           Business|       Not Yet Known|https://www.audib...|     walter Dixon|https://www.audib...|   Michael Quinlan|          123838.0|             48.0|‘Young Man - You’...|
# +-------+--------------------+-----------------+-------------------+--------------------+--------------------+-----------------+--------------------+------------------+------------------+-----------------+--------------------+

# %%
data.groupBy("author") \
.count() \
.orderBy("count", ascending=False) \
.show(10)
# Out:
# +--------------------+-----+
# |              author|count|
# +--------------------+-----+
# |Charles River Edi...|  641|
# |Harvard Business ...|  335|
# |   Geoffrey Giuliano|  219|
# |        Holly Newson|  195|
# |Robin Morgan-Bentley|  164|
# |          IntroBooks|  162|
# |      Hourly History|  122|
# |           Instaread|  119|
# |                null|  117|
# |  Edward Lucie-Smith|  102|
# +--------------------+-----+
# only showing top 10 rows

# %%
# filtering the null values
condition1 = data.rating.isNotNull()

data = data.filter(condition1)
condition1 = data.price.isNotNull()
data = data.filter(condition1)
condition1 = data.rating_count.isNotNull()
data = data.filter(condition1)

# %%
data.describe().show()
# Out:
# +-------+--------------------+-----------------+-------------------+--------------------+--------------------+-----------------+--------------------+------------------+------------------+-----------------+--------------------+
# |summary|                asin|           author|           category|              length|                link|         narrator|               price|            rating|      rating_count|     release_date|               title|
# +-------+--------------------+-----------------+-------------------+--------------------+--------------------+-----------------+--------------------+------------------+------------------+-----------------+--------------------+
# |  count|               41843|            44198|              44315|               44312|               44315|            43895|               44315|             44315|             44315|            44315|               44315|
# |   mean|     1.49163573135E9|             null|               null|                null|                null|             null|  15.663657380234493| 3.398562659384802| 134.0894374365339|36.07142857142857|   734.9545454545455|
# | stddev|3.6267760469686264E8|             null|               null|                null|                null|             null|    9.54041043540166|1.7335519567422266|1289.3522963655423| 90.8384948293241|   875.4724154514809|
# |    min|          0525499652|"""Bo"" Bottomly"| 50 Things To Know"| Brig. Gen. Leo P...|    1 hr and 49 mins|"""Bo"" Bottomly"|       Denise Kirby"|         Stu Sone"|               0.0|              0.0|"""All the Living...|
# |    max|          B07TPLMXDW|     win c. kelly|           Business|       Not Yet Known|https://www.audib...|     walter Dixon|https://www.audib...|   Michael Quinlan|          123838.0|             48.0|‘Young Man - You’...|
# +-------+--------------------+-----------------+-------------------+--------------------+--------------------+-----------------+--------------------+------------------+------------------+-----------------+--------------------+

# %%
data.show(2)
# Out:
# +----------+------------+--------------------+-----------------+--------------------+----------+-----+------+------------+------------+--------------+
# |      asin|      author|            category|           length|                link|  narrator|price|rating|rating_count|release_date|         title|
# +----------+------------+--------------------+-----------------+--------------------+----------+-----+------+------------+------------+--------------+
# |      null|Paul Stanley|Arts & Entertainment|4 hrs and 38 mins|https://www.audib...|Sean Pratt|20.52|   4.0|        78.0|  2019-04-30|Backstage Pass|
# |B0052OM9XK|  Simon Pegg|Arts & Entertainment|4 hrs and 50 mins|https://www.audib...|Simon Pegg| 24.5|   4.5|       872.0|  2011-06-09|  Nerd Do Well|
# +----------+------------+--------------------+-----------------+--------------------+----------+-----+------+------------+------------+--------------+
# only showing top 2 rows

# %%
# converting the values from string to double

from pyspark.sql.types import DoubleType

data = data.withColumn("price", data["price"].cast(DoubleType()))
data = data.withColumn("rating_count", data["rating_count"].cast(DoubleType()))
data = data.withColumn("rating", data["rating"].cast(DoubleType()))

# %%
data.show()
# Out:
# +----------+--------------------+--------------------+------------------+--------------------+--------------------+-----+------+------------+------------+--------------------+
# |      asin|              author|            category|            length|                link|            narrator|price|rating|rating_count|release_date|               title|
# +----------+--------------------+--------------------+------------------+--------------------+--------------------+-----+------+------------+------------+--------------------+
# |      null|        Paul Stanley|Arts & Entertainment| 4 hrs and 38 mins|https://www.audib...|          Sean Pratt|20.52|   4.0|        78.0|  2019-04-30|      Backstage Pass|
# |B0052OM9XK|          Simon Pegg|Arts & Entertainment| 4 hrs and 50 mins|https://www.audib...|          Simon Pegg| 24.5|   4.5|       872.0|  2011-06-09|        Nerd Do Well|
# |B077XN66F8|        Sidney Lumet|Arts & Entertainment| 7 hrs and 23 mins|https://www.audib...| Richard M. Davidson|20.99|   5.0|        90.0|  2017-12-05|       Making Movies|
# |B00C75YMJ6|      Phil Robertson|Arts & Entertainment| 4 hrs and 57 mins|https://www.audib...|Al Robertson, Phi...|20.99|   4.5|       805.0|  2013-05-07| Happy, Happy, Happy|
# |B00DCD16GE|Robert Greenberg,...|Arts & Entertainment|24 hrs and 25 mins|https://www.audib...|    Robert Greenberg|52.95|   5.0|       585.0|  2013-07-08|How to Listen to ...|
# |B0743JMWVB|        Corey Taylor|Arts & Entertainment| 7 hrs and 51 mins|https://www.audib...|        Corey Taylor|29.65|   4.5|       390.0|  2017-08-08|          America 51|
# |B008SDDV2A|Travis Langley, M...|Arts & Entertainment|10 hrs and 18 mins|https://www.audib...|    Mike Chamberlain|24.95|   4.5|      1398.0|  2012-08-06|Batman and Psycho...|
# |B07JKCJ8VF|        Maria Brophy|Arts & Entertainment| 7 hrs and 43 mins|https://www.audib...|        Maria Brophy|19.95|   4.5|        60.0|  2018-10-24|Art Money Success...|
# |B07HP8G7XC|        Nolan Gasser|Arts & Entertainment|38 hrs and 56 mins|https://www.audib...|        Nolan Gasser|40.59|   3.0|         4.0|  2019-04-30|     Why You Like It|
# |B00EFABXJ8|     Brian Jay Jones|Arts & Entertainment|21 hrs and 18 mins|https://www.audib...|      Kirby Heyborne| 42.0|   4.5|       841.0|  2013-09-24|          Jim Henson|
# |B002V1NOW2|      Philip Pullman|Arts & Entertainment|10 hrs and 45 mins|https://www.audib...|      Philip Pullman|21.48|   4.5|       176.0|  2006-12-31|Northern Lights: ...|
# |B07751DRRG|Robin Morgan-Bentley|Arts & Entertainment|           30 mins|https://www.audib...|      Salman Rushdie|  0.0|   4.5|        53.0|  2017-11-06|      Salman Rushdie|
# |B07GPWH3KS|        Holly Newson|Arts & Entertainment|           14 mins|https://www.audib...|         Max Tegmark|  0.0|   4.0|        16.0|  2018-08-21|         Max Tegmark|
# |B07NH8NNVB|Influential Indiv...|Arts & Entertainment|   1 hr and 6 mins|https://www.audib...|      Jeffrey Howard| 6.95|   4.5|        30.0|  2019-02-11|Dwayne 'The Rock'...|
# |      null|      Danny Goldberg|Arts & Entertainment| 8 hrs and 37 mins|https://www.audib...|      Danny Goldberg|27.37|   4.5|       144.0|  2019-04-02| Serving the Servant|
# |B002V1OJG2|           Alex Ross|Arts & Entertainment| 23 hrs and 7 mins|https://www.audib...|      Grover Gardner|39.95|   4.0|       381.0|  2007-12-10|   The Rest Is Noise|
# |B01H45SIVQ|Robin Morgan-Bentley|Arts & Entertainment|           22 mins|https://www.audib...|            Joe Hill|  0.0|   4.5|       162.0|  2016-06-16|            Joe Hill|
# |B01KKVT62G|  Michael S. Tyrrell|Arts & Entertainment| 2 hrs and 42 mins|https://www.audib...|  Michael S. Tyrrell| 6.95|   4.5|        58.0|  2016-08-19|The Sound of Heal...|
# |B01K5R02RS|          Mark Frost|Arts & Entertainment| 9 hrs and 33 mins|https://www.audib...|Len Cariou, Mark ...|27.99|   4.5|      1675.0|  2016-10-18|The Secret Histor...|
# |B005UOK9QG|         Kris Jenner|Arts & Entertainment| 9 hrs and 18 mins|https://www.audib...|Marcia Strassman,...|27.99|   4.0|       355.0|  2011-11-01|Kris Jenner...and...|
# +----------+--------------------+--------------------+------------------+--------------------+--------------------+-----+------+------------+------------+--------------------+
# only showing top 20 rows

# %%
# vector assembler to create the model from the data

# VectorAssembler can take inout columns and transform them into a single column (named “predictors”)

from pyspark.ml.feature import VectorAssembler
inputcols = ["price",  "rating_count"]
assembler = VectorAssembler(inputCols= inputcols,
                            outputCol = "predictors")

# %%
predictors = assembler.setHandleInvalid("skip").transform(data)
predictors.columns
# Out:
# ['asin',
#  'author',
#  'category',
#  'length',
#  'link',
#  'narrator',
#  'price',
#  'rating',
#  'rating_count',
#  'release_date',
#  'title',
#  'predictors']

# %%
# collect the predictors column and target column in their separate datframe

model_data = predictors.select("predictors", "rating")
model_data.show(10,truncate=False)
model_data.na.drop().show()
# Out:
# +--------------+------+
# |predictors    |rating|
# +--------------+------+
# |[20.52,78.0]  |4.0   |
# |[24.5,872.0]  |4.5   |
# |[20.99,90.0]  |5.0   |
# |[20.99,805.0] |4.5   |
# |[52.95,585.0] |5.0   |
# |[29.65,390.0] |4.5   |
# |[24.95,1398.0]|4.5   |
# |[19.95,60.0]  |4.5   |
# |[40.59,4.0]   |3.0   |
# |[42.0,841.0]  |4.5   |
# +--------------+------+
# only showing top 10 rows
#
# +--------------+------+
# |    predictors|rating|
# +--------------+------+
# |  [20.52,78.0]|   4.0|
# |  [24.5,872.0]|   4.5|
# |  [20.99,90.0]|   5.0|
# | [20.99,805.0]|   4.5|
# | [52.95,585.0]|   5.0|
# | [29.65,390.0]|   4.5|
# |[24.95,1398.0]|   4.5|
# |  [19.95,60.0]|   4.5|
# |   [40.59,4.0]|   3.0|
# |  [42.0,841.0]|   4.5|
# | [21.48,176.0]|   4.5|
# |    [0.0,53.0]|   4.5|
# |    [0.0,16.0]|   4.0|
# |   [6.95,30.0]|   4.5|
# | [27.37,144.0]|   4.5|
# | [39.95,381.0]|   4.0|
# |   [0.0,162.0]|   4.5|
# |   [6.95,58.0]|   4.5|
# |[27.99,1675.0]|   4.5|
# | [27.99,355.0]|   4.0|
# +--------------+------+
# only showing top 20 rows

# %%
# split the data into testing and training

train_data,test_data = model_data.randomSplit([0.8,0.2])

# %%
# training the regression model

from pyspark.ml.regression import LinearRegression

lr = LinearRegression(
    featuresCol = 'predictors', 
    labelCol = 'rating')

lrModel = lr.fit(train_data)

# %%
pred = lrModel.evaluate(test_data)

# %%
# acces the model parameters

lrModel.coefficients
# Out:
# DenseVector([0.0499, 0.0])

# %%
lrModel.intercept
# Out:
# 2.607785884371491

# %%
# View the final model predictions on the test data

pred.predictions.show(10)
# Out:
# +----------+------+------------------+
# |predictors|rating|        prediction|
# +----------+------+------------------+
# | (2,[],[])|   0.0| 2.607785884371491|
# | (2,[],[])|   0.0| 2.607785884371491|
# | (2,[],[])|   0.0| 2.607785884371491|
# | [0.0,1.0]|   2.0|2.6078319015612497|
# | [0.0,1.0]|   3.0|2.6078319015612497|
# | [0.0,1.0]|   3.0|2.6078319015612497|
# | [0.0,1.0]|   3.0|2.6078319015612497|
# | [0.0,1.0]|   3.0|2.6078319015612497|
# | [0.0,1.0]|   3.0|2.6078319015612497|
# | [0.0,1.0]|   3.0|2.6078319015612497|
# +----------+------+------------------+
# only showing top 10 rows

# %%
# For more detailed information on the model performance

from pyspark.ml.evaluation import RegressionEvaluator
eval = RegressionEvaluator(
    labelCol="rating", 
    predictionCol="prediction", 
    metricName="rmse")

# %%
# Computing some statistics for the model

rmse = eval.evaluate(pred.predictions)
print("rmse: ", rmse)
mse = eval.evaluate(pred.predictions, {eval.metricName: "mse"})
print("mse: ", mse)
mae = eval.evaluate(pred.predictions, {eval.metricName: "mae"})
print("mae: ", mae)
r2 = eval.evaluate(pred.predictions, {eval.metricName: "r2"})
print("r2: ", r2)
# Out:
# rmse:  1.659140253662445
# mse:  2.752746381323083
# mae:  1.2934172060348403
# r2:  0.07246204701103753

# %%
# Gradient boosted tree regression

from pyspark.ml.regression import GBTRegressor
gbt = GBTRegressor(featuresCol = 'predictors', labelCol = 'rating', maxIter=10)
gbt_model = gbt.fit(train_data)
gbt_predictions = gbt_model.transform(test_data)
gbt_predictions.select('prediction', 'rating', 'predictors').show(5)
# Out:
# +--------------------+------+----------+
# |          prediction|rating|predictors|
# +--------------------+------+----------+
# |-0.04924867870855...|   0.0| (2,[],[])|
# |-0.04924867870855...|   0.0| (2,[],[])|
# |-0.04924867870855...|   0.0| (2,[],[])|
# |   3.684271727528901|   2.0| [0.0,1.0]|
# |   3.684271727528901|   3.0| [0.0,1.0]|
# +--------------------+------+----------+
# only showing top 5 rows

# %%
gbt_evaluator = RegressionEvaluator(
    labelCol="rating", predictionCol="prediction", metricName="rmse")
rmse = gbt_evaluator.evaluate(gbt_predictions)
print("Root Mean Squared Error (RMSE) on test data = %g" % rmse)
# Out:
# Root Mean Squared Error (RMSE) on test data = 0.6546

# %%
# Decision Tree Regression

from pyspark.ml.regression import DecisionTreeRegressor
dt = DecisionTreeRegressor(featuresCol ='predictors', labelCol = 'rating')
dt_model = dt.fit(train_data)
dt_predictions = dt_model.transform(test_data)
dt_predictions.select('prediction', 'rating', 'predictors').show(5)
# Out:
# +------------------+------+----------+
# |        prediction|rating|predictors|
# +------------------+------+----------+
# |               0.0|   0.0| (2,[],[])|
# |               0.0|   0.0| (2,[],[])|
# |               0.0|   0.0| (2,[],[])|
# |3.8414264036418815|   2.0| [0.0,1.0]|
# |3.8414264036418815|   3.0| [0.0,1.0]|
# +------------------+------+----------+
# only showing top 5 rows

# %%
dt_evaluator = RegressionEvaluator(
    labelCol="rating", predictionCol="prediction", metricName="rmse")
rmse = dt_evaluator.evaluate(dt_predictions)
print("Root Mean Squared Error (RMSE) on test data = %g" % rmse)
# Out:
# Root Mean Squared Error (RMSE) on test data = 0.656283
